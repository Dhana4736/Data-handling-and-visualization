# %% [markdown]
# <a href="https://colab.research.google.com/github/Dhana4736/Data-handling-and-visualization/blob/main/dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('/content/drive/MyDrive/data (1) (1).csv')
df.head()
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %%
df=pd.read_csv('/content/drive/MyDrive/data (1) (1).csv')
df.tail()
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4

# %%
df.shape
# Out:
# (169, 4)

# %%
print(df.to_markdown())
# Out:
# |     |   Duration |   Pulse |   Maxpulse |   Calories |
# |----:|-----------:|--------:|-----------:|-----------:|
# |   0 |         60 |     110 |        130 |      409.1 |
# |   1 |         60 |     117 |        145 |      479   |
# |   2 |         60 |     103 |        135 |      340   |
# |   3 |         45 |     109 |        175 |      282.4 |
# |   4 |         45 |     117 |        148 |      406   |
# |   5 |         60 |     102 |        127 |      300   |
# |   6 |         60 |     110 |        136 |      374   |
# |   7 |         45 |     104 |        134 |      253.3 |
# |   8 |         30 |     109 |        133 |      195.1 |
# |   9 |         60 |      98 |        124 |      269   |
# |  10 |         60 |     103 |        147 |      329.3 |
# |  11 |         60 |     100 |        120 |      250.7 |
# |  12 |         60 |     106 |        128 |      345.3 |
# |  13 |         60 |     104 |        132 |      379.3 |
# ...

# %%
df.isnull().sum()
# Out:
# Duration    0
# Pulse       0
# Maxpulse    0
# Calories    5
# dtype: int64

# %%
newdf=df.dropna()
newdf.shape
# Out:
# (164, 4)

# %%
df.shape
# Out:
# (169, 4)

# %%
x=df["Calories"].mean()
df.fillna(x,inplace=True)

# %%
print(df.to_markdown())
# Out:
# |     |   Duration |   Pulse |   Maxpulse |   Calories |
# |----:|-----------:|--------:|-----------:|-----------:|
# |   0 |         60 |     110 |        130 |     409.1  |
# |   1 |         60 |     117 |        145 |     479    |
# |   2 |         60 |     103 |        135 |     340    |
# |   3 |         45 |     109 |        175 |     282.4  |
# |   4 |         45 |     117 |        148 |     406    |
# |   5 |         60 |     102 |        127 |     300    |
# |   6 |         60 |     110 |        136 |     374    |
# |   7 |         45 |     104 |        134 |     253.3  |
# |   8 |         30 |     109 |        133 |     195.1  |
# |   9 |         60 |      98 |        124 |     269    |
# |  10 |         60 |     103 |        147 |     329.3  |
# |  11 |         60 |     100 |        120 |     250.7  |
# |  12 |         60 |     106 |        128 |     345.3  |
# |  13 |         60 |     104 |        132 |     379.3  |
# ...

# %%
x=df["Calories"].median()
df.fillna(x,inplace=True)

# %%
print(df.to_markdown())

# %%
x=df["Calories"].mode()[0]
df.fillna(x,inplace=True)

# %%
print(df.to_markdown())

# %%
df=pd.read_csv('/content/drive/MyDrive/data (1) (1).csv')
df.head()

# %%
x=df["Calories"].median()
df.fillna(x,inplace=True)

# %%
print(df.to_markdown())

# %%
df=pd.read_csv('/content/drive/MyDrive/data (1) (1).csv')
df.head()

# %%
print(df.to_markdown())

# %%
df.fillna(130,inplace=True)

# %%
print(df.to_markdown())

# %%
df=pd.read_csv('/content/drive/MyDrive/data (1) (1).csv')
df.head()

# %%
x=df["Calories"].mean()
df.fillna(x,inplace=True)

# %%
print(df.to_markdown())

# %%
df=pd.read_csv('/content/drive/MyDrive/data (1) (1).csv')
df.head()

# %%
x=df["Calories"].median()
df.fillna(x,inplace=True)

# %%
print(df.to_markdown())

# %%
df=pd.read_csv('/content/drive/MyDrive/data (1) (1).csv')
df.head()
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %%
x=df["Calories"].mode()[0]
df.fillna(x,inplace=True)

# %%
print(df.to_markdown())

# %%
df.isnull().sum()
# Out:
# Duration    0
# Pulse       0
# Maxpulse    0
# Calories    5
# dtype: int64

# %%
df=pd.read_csv('/content/drive/MyDrive/data (1) (1).csv')
df.head()
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %%
df.isnull().sum()

# %%
for columb in df.columns:
    print(columb)
# Out:
# Duration
# Pulse
# Maxpulse
# Calories

# %%
df.corr()

# %%
df.drop_duplicates(inplace=True
                   )

# %%
df.shape
# Out:
# (162, 4)

# %%
print(df.loc[0])
# Out:
# Duration     60.0
# Pulse       110.0
# Maxpulse    130.0
# Calories    409.1
# Name: 0, dtype: float64

# %%
df.loc[7,'Calories']=45
print(df.to_string())

# %%
df.loc[8,'Calories']=45
print(df.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134      45.0
# 8          30    109       133      45.0
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...
