# %% [markdown]
# <a href="https://colab.research.google.com/github/Dhana4736/Data-handling-and-visualization/blob/main/Time_series_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **TRENDS**

# %%
import pandas as pd
import matplotlib.pyplot as plt
data={
    "Date":pd.to_datetime(["2022-01-01","2022-02-01","2022-03-01","2022-04-01","2022-05-01","2022-06-01","2022-07-01","2022-08-01"]),
    "value":[10,15,22,28,35,42,48,55]
}
df=pd.DataFrame(data)
df.set_index("Date",inplace=True)

plt.figure(figsize=(10,6))
plt.plot(df.index, df["value"],marker='X')
plt.xlabel("Date")
plt.ylabel("Value")
plt.title("Time series with trend")
plt.grid(True)
plt.show()

# %% [markdown]
# **SEASONALITY**

# %%
import pandas as pd
import matplotlib.pyplot as plt
data={
    "Date":pd.to_datetime(["2022-01-01","2022-02-01","2022-03-01","2022-04-01","2022-05-01","2022-06-01","2022-07-01","2022-08-01","2022-09-01","2022-10-01","2022-11-01","2022-12-01"]),
    "value":[10,20,40,24,45,60,70,45,60,80,55,100]
}
df=pd.DataFrame(data)
df.set_index("Date",inplace=True)

plt.figure(figsize=(10,6))
plt.plot(df.index, df["value"],marker='X')
plt.xlabel("Date")
plt.ylabel("Value")
plt.title("Time series with seasonality")
plt.grid(True)
plt.show()
